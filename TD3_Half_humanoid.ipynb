# %% [markdown]
# # Implementation TD3

# %% [markdown]
# # Importing the libraries

# %%
import os
import time
import random
import numpy as np
import matplotlib.pyplot as plt
import pybullet_envs
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
from gym import wrappers
from torch.autograd import Variable
from collections import deque

# %% [markdown]
# # Step1: we initialize ehr Experience Replay Memory

# %%
class ReplayBuffer(object):
    def __init__(self, max_size = 1e6):
        self.storage = []
        self.max_size = max_size
        self.ptr = 0
        
    def add(self, transition):
        if len(self.storage) == self.max_size:
            self.storage[int(self.ptr)] = transition
            self.ptr = (self.ptr +1) % self.max_size
        else:
            self.storage.append(transition)
            
    def sample(self, batch_size):
        ind = np.random.randint(0, len(self.storage), size = batch_size)
        batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = [], [], [], [], []
        for i in ind:
            state, next_state, action, reward, done = self.storage[i]
            batch_states.append(np.array(state, copy=False))
            batch_next_states.append(np.array(next_state, copy=False))
            batch_actions.append(np.array(action, copy=False))
            batch_rewards.append(np.array(reward, copy=False))
            batch_dones.append(np.array(done, copy=False))
        return np.array(batch_states), np.array(batch_next_states), np.array(batch_actions), np.array(batch_rewards).reshape(-1,1), np.array(batch_dones).reshape(-1,1)

# %% [markdown]
# # Step 2: Build Neural Network for Actors

# %%
class Actor(nn.Module):
    
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()
        self.layer_1 = nn.Linear(state_dim, 400)
        self.layer_2 = nn.Linear(400, 300)
        self.layer_3 = nn.Linear(300, action_dim)
        self.max_action = max_action
        
    def forward(self, x):
        x = F.relu(self.layer_1(x))
        x = F.relu(self.layer_2(x))
        x = self.max_action*torch.tanh(self.layer_3(x))
        return x

# %% [markdown]
# # Step 3: Build Neural Network for crtitic

# %%
class Critic(nn.Module):
    
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()
        # first twin NN model
        self.layer_1 = nn.Linear(state_dim+action_dim, 400)
        self.layer_2 = nn.Linear(400, 300)
        self.layer_3 = nn.Linear(300, 1)
        # Second twin NN model
        self.layer_4 = nn.Linear(state_dim+action_dim, 400)
        self.layer_5 = nn.Linear(400, 300)
        self.layer_6 = nn.Linear(300, 1)
        
    def forward(self, x, u):
        xu = torch.cat([x, u], 1)
        #first propoagation
        x1 = F.relu(self.layer_1(xu))
        x1 = F.relu(self.layer_2(x1))
        x1 = self.layer_3(x1)
        # second propogation
        x2 = F.relu(self.layer_4(xu))
        x2 = F.relu(self.layer_5(x2))
        x2 = self.layer_6(x2)
        return x1, x2
    
    def q1(self, x, u):
        xu = torch.cat([x, u], 1)
        x1 = F.relu(self.layer_1(xu))
        x1 = F.relu(self.layer_2(x1))
        x1 = self.layer_3(x1)
        return x1

# %% [markdown]
# # Step 4 to 15: Training Process

# %%
#Slecting the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device.type
# Out:
# 'cuda'

# %%
# Building the whole Training Process into a class

class TD3(object):
    
    def __init__(self, state_dim, action_dim, max_action):
        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target = Actor (state_dim, action_dim, max_action).to(device)
        self.actor_target.load_state_dict(self.actor.state_dict())
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters())
        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = Critic (state_dim, action_dim).to(device)
        self.critic_target.load_state_dict(self.critic.state_dict())
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters())
        self.max_action = max_action
        
    def select_action(self, state):
        state = torch.Tensor(state.reshape(1,-1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()
    
    def train(self, replay_buffer, iterations, batch_size=100, discount = .99, tau=.005, policy_noise=.2, noise_clip=.5, policy_freq=2):
        
        for it in range(iterations):
            
            # Step4: we sample a batch of transitions (s,s',a,r) from emory
            batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = replay_buffer.sample(batch_size)
            state = torch.Tensor(batch_states).to(device)
            next_state = torch.Tensor(batch_next_states).to(device)
            action = torch.Tensor(batch_actions).to(device)
            reward = torch.Tensor(batch_rewards).to(device)
            done = torch.Tensor(batch_dones).to(device)
            
            # Step5: from the next state s', the Actor target plays the next action a'
            next_action = self.actor_target(next_state)
            
            # Step6: add gaussian noise to next_action and we clamp(clip) it in arange of values supported by the environmenrt
            noise = torch.Tensor(batch_actions).data.normal_(0, policy_noise).to(device)
            noise = noise.clamp(-noise_clip,noise_clip)
            next_action = (next_action + noise).clamp(-self.max_action, self.max_action)
            
            # Step7: two critic target get (s',a') and return qt1(s',a'), qt2(s', a')
            target_q1, target_q2 = self.critic_target(next_state, next_action)
            
            # Step8: min(q_values) to represent approximate values of the next state
            target_q = torch.min(target_q1, target_q2)
            
            # Step9: Final target of the two critic model(here we have to consider if we are in the last transition of episode or not)
            target_q = reward + ((1-done) * discount * target_q).detach()
            
            # Step10: two critic model take (s,a) and return Q1(s,a), Q2(s,a) with target Q
            current_q1, current_q2 = self.critic(state, action)
            
            # Step11: calculate loss function with mse
            critic_loss = F.mse_loss(current_q1, target_q) + F.mse_loss(current_q2, target_q)
            
            # Step12: BackPropogation
            self.critic_optimizer.zero_grad()
            critic_loss.backward()
            self.critic_optimizer.step()
            
            # Step13: update actor model by gradient ascent
            # Gradient ascent that is very impormant:
            # Gradient descent is minimizing a function and gradient ascent is like gradient descent but in minus of that function
            if it % policy_freq == 0:
                actor_loss = -self.critic.q1(state, self.actor(state)).mean()
                self.actor_optimizer.zero_grad()
                actor_loss.backward()
                self.actor_optimizer.step()
                
                # Step14: update weights of the actor target by polyak average
                for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                    target_param.data.copy_(tau*param.data +(1 - tau)*target_param.data)
                    
                    
                # Step15: update wights of the critic target by polyak average
                for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                    target_param.data.copy_(tau*param.data +(1-tau)*target_param.data)
               
    # Making a save method to save a trained model
    def save(self, filename, directory):
        torch.save(self.actor.state_dict(), "%s%s_actor.pth" % (directory, filename))
        torch.save(self.critic.state_dict(), "%s%s_critic.pth" % (directory, filename))
        
    # Making a load method to load a pre_trained model
    def load(self, filename, directory):
        self.actor.load_state_dict(torch.load("%s%s_actor.pth" % (directory, filename)))
        self.critic.load_state_dict(torch.load("%s%s_critic.pth" % (directory, filename)))

# %% [markdown]
# # Make a function that evaluate the policy by calculating rits average reward over 10 episodes

# %%
def evaluate_policy(policy, eval_episodes = 10):
    avg_reward = 0
    for _ in range(eval_episodes):
        obs = env.reset()
        done = False
        while not done:
            action = policy.select_action(np.array(obs))
            obs, reward, done, _ = env.step(action)
            avg_reward += reward
    avg_reward /= eval_episodes
    print("----------------------------------------")
    print("Average Reward over the evaluation step: %f" % (avg_reward))
    print("----------------------------------------")
        
    return avg_reward

# %% [markdown]
# # Set parameters

# %%
env_name = "Walker2DBulletEnv-v0" # Name of a environment (set it to any Continous environment you want)
seed = 0 # Random seed number
start_timesteps = 1e4 ## Number of iterations/timesteps before which the model randomly chooses an action, and after which it starts to use the policy network
eval_freq = 5e3 ## How often the evaluation step is performed (after how many timesteps)
max_timesteps = 5e5 # Total number of iterations/timesteps
save_models = True # Boolean checker whether or not to save the pre-trained model
expl_noise = 0.1 # Exploration noise - STD value of exploration Gaussian noise
batch_size = 100 # Size of the batch
discount = 0.99 # Discount factor gamma, used in the calculation of the total discounted reward
tau = 0.005 # Target network update rate
policy_noise = 0.2 # STD of Gaussian noise added to the actions for the exploration purposes
noise_clip = 0.5 # Maximum value of the Gaussian noise added to the actions (policy)
policy_freq = 2 # Number of iterations to wait before the policy network (Actor model) is updated

# %% [markdown]
# # Create a file name for the two saved models: the Actor and Critic models

# %%
file_name = "%s_%s_%s" %("TD3", env_name, str(seed))
print ("---------------------------------------")
print ("Settings: %s" % (file_name))
print ("---------------------------------------")
# Out:
# ---------------------------------------
# Settings: TD3_Walker2DBulletEnv-v0_0
# ---------------------------------------

# %% [markdown]
# # Create a folde inside which will be saved the trained model

# %%
if not os.path.exists("./results"):
    os.makedirs("./results")
if save_models and not os.path.exists("./pytorch_models"):
    os.makedirs("./pytorch_models")

# %% [markdown]
# # Create the PyBullet environment
#
# ### This is for installing gym
#
# https://towardsdatascience.com/how-to-install-openai-gym-in-a-windows-environment-338969e24d30

# %%
env = gym.make(env_name)
# Out:
# C:\Users\hamed\anaconda3\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# # Set seeds and we get the necessary information on the states and actions in the choosen environmet

# %%
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

# %% [markdown]
# # Create the Network

# %%
policy = TD3(state_dim, action_dim, max_action)

# %% [markdown]
# # Create the Exprience Replay memory

# %%
replay_buffer = ReplayBuffer()

# %% [markdown]
# # Define a list where all the evaluation results over 10 episodes are stored

# %%
evaluations = [evaluate_policy(policy)]
# Out:
# ----------------------------------------
# Average Reward over the evaluation step: 264.967711
# ----------------------------------------

# %% [markdown]
# # Create a new folder directory in which the final results (video of the agent will be populated

# %%
def mkdir(base, name):
    path = os.path.join(base, name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path
work_dir = mkdir("exp", "brs")
monitor_dir = mkdir(work_dir, "monitor")
max_episode_steps = env._max_episode_steps
save_env_vid = False
if save_env_vid:
    env = wrappers.Monitor(env, monitor_dir, force = True)
    env.reset()

# %% [markdown]
# # Initialize the variables

# %%
total_timesteps = 0
timesteps_since_eval = 0
episode_num = 0
done = True
t0 = time.time()

# %% [markdown]
# # Training

# %%
# Start the main loop over 500,000 timesteps
while total_timesteps < max_timesteps:
    
    # if the episode is done
    if done:
        
        # if we are not at the very begining, we start the training process of the model
        if total_timesteps !=0:
            print("Total Timesteps: {} Episode Num: {} Reward: {}".format(total_timesteps, episode_num, episode_reward))
            policy.train(replay_buffer, episode_timesteps, batch_size, discount, tau, policy_noise, noise_clip, policy_freq)
            
        if timesteps_since_eval >= eval_freq:
            timesteps_since_eval %= eval_freq
            evaluations.append(evaluate_policy(policy))
            policy.save(file_name, directory="./pytorch_models")
            np.save("./results/%s" % (file_name), evaluations)
            
        # When the training step is done, we reset the state of the environment
        
        obs = env.reset()
        
        #et the Done to False
        
        #set rewards and episode timesteps to zero
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1
        
        
    # Before 10000 timesteps, we play random actions
    if total_timesteps < start_timesteps:
        action = env.action_space.sample()
    else: #After 10000 times we switch to the model
        action = policy.select_action(np.array(obs))
        
        # if the explore_noise parameter is not 0, we add noise to the action and we clip it
        if expl_noise != 0:
            action = (action +np.random.normal(0, expl_noise, size=env.action_space.shape[0])).clip(env.action_space.low, env.action_space.high)
    
    # the agent performs the action in the environment, then reaches the next state and receives the reward
    new_obs, reward, done, _ = env.step(action)
    
    #we check if the episode is done
    done_bool = 0 if episode_timesteps + 1 == env._max_episode_steps else float(done)
    
    # We increase the total rewrd
    episode_reward += reward
    
    # We store the new transition into the experiemce replay memory
    replay_buffer.add((obs, new_obs, action, reward, done_bool))
    
    # We update the state, the episode timestep, the total timesteps, and the timesteps scince the evaluation of the policy
    obs = new_obs
    episode_timesteps +=1
    total_timesteps +=1
    timesteps_since_eval +=1
    
    
# We add the last policy evaluation to our list of evaluation and we save our model
evaluations.append(evaluate_policy(policy))
if save_models: policy.save("%s" % (file_name), directory="./pytorch_models")
np.save("./results/%s" % (file_name), evaluations)
# Out:
# Total Timesteps: 8 Episode Num: 1 Reward: 12.367021041171391
# Total Timesteps: 18 Episode Num: 2 Reward: 15.138441208351287
# Total Timesteps: 28 Episode Num: 3 Reward: 14.53532861542044
# Total Timesteps: 46 Episode Num: 4 Reward: 19.255210655427074
# Total Timesteps: 59 Episode Num: 5 Reward: 16.760800392518284
# Total Timesteps: 77 Episode Num: 6 Reward: 20.737017455465686
# Total Timesteps: 116 Episode Num: 7 Reward: 33.58704801278073
# Total Timesteps: 123 Episode Num: 8 Reward: 13.203495901290443
# Total Timesteps: 141 Episode Num: 9 Reward: 19.716654729914442
# Total Timesteps: 161 Episode Num: 10 Reward: 22.022580836257838
# Total Timesteps: 176 Episode Num: 11 Reward: 19.437172561748593
# Total Timesteps: 193 Episode Num: 12 Reward: 17.776449667652194
# Total Timesteps: 207 Episode Num: 13 Reward: 15.969880578648006
# Total Timesteps: 217 Episode Num: 14 Reward: 15.107119100460842
# Total Timesteps: 230 Episode Num: 15 Reward: 14.874611434785766
# Total Timesteps: 254 Episode Num: 16 Reward: 22.129434246693563
# Total Timesteps: 928 Episode Num: 63 Reward: 17.367309190338712
# Total Timesteps: 941 Episode Num: 64 Reward: 13.94192494618619
# Total Timesteps: 951 Episode Num: 65 Reward: 13.66411277080042
# Total Timesteps: 959 Episode Num: 66 Reward: 12.363598409414408
# Total Timesteps: 972 Episode Num: 67 Reward: 16.635143234464337
# Total Timesteps: 980 Episode Num: 68 Reward: 13.496497414182521
# Total Timesteps: 991 Episode Num: 69 Reward: 15.244693450567137
# Total Timesteps: 1003 Episode Num: 70 Reward: 16.27607301200478
# Total Timesteps: 1013 Episode Num: 71 Reward: 13.240285408616183
# Total Timesteps: 1021 Episode Num: 72 Reward: 15.012210862731445
# Total Timesteps: 1030 Episode Num: 73 Reward: 12.58621800623514
# Total Timesteps: 1054 Episode Num: 74 Reward: 24.110255812264224
# Total Timesteps: 1065 Episode Num: 75 Reward: 15.295196322220725
# Total Timesteps: 1082 Episode Num: 76 Reward: 17.334888171253258
# Total Timesteps: 1104 Episode Num: 77 Reward: 20.620181570541163
# Total Timesteps: 1119 Episode Num: 78 Reward: 18.354753541904213
# Total Timesteps: 1133 Episode Num: 79 Reward: 16.5619270964904
# Total Timesteps: 1154 Episode Num: 80 Reward: 19.42542240041221
# Total Timesteps: 1171 Episode Num: 81 Reward: 16.88320292466815
# Total Timesteps: 1191 Episode Num: 82 Reward: 19.89360825413314
# Total Timesteps: 1208 Episode Num: 83 Reward: 14.692135102138854
# Total Timesteps: 1221 Episode Num: 84 Reward: 14.506807201770426
# Total Timesteps: 1236 Episode Num: 85 Reward: 19.021762291883352
# Total Timesteps: 1248 Episode Num: 86 Reward: 14.874531067762293
# Total Timesteps: 1269 Episode Num: 87 Reward: 17.18295141452836
# Total Timesteps: 1276 Episode Num: 88 Reward: 13.613935704895994
# Total Timesteps: 1285 Episode Num: 89 Reward: 13.192786653256919
# Total Timesteps: 1299 Episode Num: 90 Reward: 14.386939223893568
# Total Timesteps: 1306 Episode Num: 91 Reward: 12.070510813091824
# Total Timesteps: 1314 Episode Num: 92 Reward: 14.185838576467358
# Total Timesteps: 1326 Episode Num: 93 Reward: 16.60216097433149
# Total Timesteps: 1340 Episode Num: 94 Reward: 15.647182162756508
# Total Timesteps: 1358 Episode Num: 95 Reward: 17.916290289466268
# Total Timesteps: 1372 Episode Num: 96 Reward: 18.048004004964604
# Total Timesteps: 1390 Episode Num: 97 Reward: 18.78221110766317
# Total Timesteps: 1402 Episode Num: 98 Reward: 15.99578973865864
# Total Timesteps: 1415 Episode Num: 99 Reward: 17.125927352459982
# Total Timesteps: 1429 Episode Num: 100 Reward: 17.417676366877277
# Total Timesteps: 1441 Episode Num: 101 Reward: 15.959455656292267
# Total Timesteps: 1451 Episode Num: 102 Reward: 16.50302757721947
# Total Timesteps: 1459 Episode Num: 103 Reward: 13.228902204806216
# Total Timesteps: 1466 Episode Num: 104 Reward: 10.836218095563526
# Total Timesteps: 1477 Episode Num: 105 Reward: 14.663064977353496
# Total Timesteps: 1492 Episode Num: 106 Reward: 17.089812543867446
# Total Timesteps: 1503 Episode Num: 107 Reward: 15.757697032585565
# Total Timesteps: 1516 Episode Num: 108 Reward: 10.97971719832276
# Total Timesteps: 1527 Episode Num: 109 Reward: 15.630348349736597
# Total Timesteps: 1536 Episode Num: 110 Reward: 12.668834864372911
# Total Timesteps: 1543 Episode Num: 111 Reward: 11.795966462307844
# Total Timesteps: 1553 Episode Num: 112 Reward: 14.965941287300666
# Total Timesteps: 1565 Episode Num: 113 Reward: 17.029752636616465
# Total Timesteps: 1575 Episode Num: 114 Reward: 14.566373053276038
# Total Timesteps: 1588 Episode Num: 115 Reward: 15.103617527724419
# Total Timesteps: 1599 Episode Num: 116 Reward: 14.479892851297334
# Total Timesteps: 1616 Episode Num: 117 Reward: 19.92976016514003
# Total Timesteps: 1633 Episode Num: 118 Reward: 19.340630231084653
# Total Timesteps: 1643 Episode Num: 119 Reward: 13.75771377516794
# Total Timesteps: 1653 Episode Num: 120 Reward: 13.370392510698002
# Total Timesteps: 1664 Episode Num: 121 Reward: 12.539380119474663
# Total Timesteps: 1682 Episode Num: 122 Reward: 19.59878775469406
# Total Timesteps: 1699 Episode Num: 123 Reward: 14.959163237994655
# Total Timesteps: 1715 Episode Num: 124 Reward: 17.997431481514646
# Total Timesteps: 1727 Episode Num: 125 Reward: 16.36433409073943
# Total Timesteps: 1739 Episode Num: 126 Reward: 15.141966095118551
# Total Timesteps: 1752 Episode Num: 127 Reward: 15.948090938037783
# Total Timesteps: 1765 Episode Num: 128 Reward: 15.97819658155495
# Total Timesteps: 1777 Episode Num: 129 Reward: 16.20794262449635
# Total Timesteps: 1796 Episode Num: 130 Reward: 22.558692131495626
# Total Timesteps: 1804 Episode Num: 131 Reward: 13.194153127520986
# Total Timesteps: 1819 Episode Num: 132 Reward: 17.589314975070007
# Total Timesteps: 1833 Episode Num: 133 Reward: 17.137415794239494
# Total Timesteps: 1847 Episode Num: 134 Reward: 15.917769729891731
# Total Timesteps: 1860 Episode Num: 135 Reward: 15.310148253277294
# Total Timesteps: 1875 Episode Num: 136 Reward: 18.58137039417052
# Total Timesteps: 1887 Episode Num: 137 Reward: 15.866694850425123
# Total Timesteps: 1898 Episode Num: 138 Reward: 14.726162315173132
# Total Timesteps: 1918 Episode Num: 139 Reward: 18.19551192680665
# Total Timesteps: 1943 Episode Num: 140 Reward: 24.623230324783073
# Total Timesteps: 1950 Episode Num: 141 Reward: 12.011448140497668
# Total Timesteps: 1965 Episode Num: 142 Reward: 15.741926856135251
# Total Timesteps: 1975 Episode Num: 143 Reward: 15.201354245898257
# Total Timesteps: 1996 Episode Num: 144 Reward: 21.274259909923423
# Total Timesteps: 2006 Episode Num: 145 Reward: 14.137435835237556
# Total Timesteps: 2031 Episode Num: 146 Reward: 19.886165635260113
# Total Timesteps: 2041 Episode Num: 147 Reward: 14.946214817336294
# Total Timesteps: 2049 Episode Num: 148 Reward: 14.070589237117384
# Total Timesteps: 2059 Episode Num: 149 Reward: 14.562548514534138
# Total Timesteps: 2081 Episode Num: 150 Reward: 21.042468803741215
# Total Timesteps: 8334 Episode Num: 589 Reward: 16.123921821394468
# Total Timesteps: 8346 Episode Num: 590 Reward: 15.301252462113919
# Total Timesteps: 8371 Episode Num: 591 Reward: 21.791445656548607
# Total Timesteps: 8394 Episode Num: 592 Reward: 22.40703260463488
# Total Timesteps: 8403 Episode Num: 593 Reward: 13.731692728950293
# Total Timesteps: 8418 Episode Num: 594 Reward: 18.334735264122717
# Total Timesteps: 8430 Episode Num: 595 Reward: 14.921244409991779
# Total Timesteps: 8448 Episode Num: 596 Reward: 15.705237619944093
# Total Timesteps: 8459 Episode Num: 597 Reward: 15.428463002266653
# Total Timesteps: 8481 Episode Num: 598 Reward: 22.261445558947162
# Total Timesteps: 8491 Episode Num: 599 Reward: 14.111889867816354
# Total Timesteps: 8501 Episode Num: 600 Reward: 14.011426059965743
# Total Timesteps: 8519 Episode Num: 601 Reward: 21.853169976940265
# Total Timesteps: 8528 Episode Num: 602 Reward: 14.07544136426295
# Total Timesteps: 8547 Episode Num: 603 Reward: 20.032448750620823
# Total Timesteps: 8559 Episode Num: 604 Reward: 15.44212751678715
# Total Timesteps: 8570 Episode Num: 605 Reward: 14.558089073811427
# Total Timesteps: 8580 Episode Num: 606 Reward: 13.591056022357952
# Total Timesteps: 8593 Episode Num: 607 Reward: 15.342945824595516
# Total Timesteps: 8613 Episode Num: 608 Reward: 17.25851893249201
# Total Timesteps: 8636 Episode Num: 609 Reward: 24.553782020109068
# Total Timesteps: 8652 Episode Num: 610 Reward: 14.679984198020245
# Total Timesteps: 8664 Episode Num: 611 Reward: 16.165358181350165
# Total Timesteps: 8673 Episode Num: 612 Reward: 14.277825132739961
# Total Timesteps: 8687 Episode Num: 613 Reward: 17.67940086315939
# Total Timesteps: 8696 Episode Num: 614 Reward: 12.759529400678002
# Total Timesteps: 8710 Episode Num: 615 Reward: 18.4111770760006
# Total Timesteps: 8723 Episode Num: 616 Reward: 15.861293003964239
# Total Timesteps: 8743 Episode Num: 617 Reward: 23.17991639306128
# Total Timesteps: 8754 Episode Num: 618 Reward: 15.232521479086426
# Total Timesteps: 8776 Episode Num: 619 Reward: 21.552202628192024
# Total Timesteps: 8792 Episode Num: 620 Reward: 17.22128332916327
# Total Timesteps: 8803 Episode Num: 621 Reward: 14.955763533746358
# Total Timesteps: 8815 Episode Num: 622 Reward: 15.281223549989226
# Total Timesteps: 8829 Episode Num: 623 Reward: 15.577877761470155
# Total Timesteps: 8836 Episode Num: 624 Reward: 11.849040080972191
# Total Timesteps: 8855 Episode Num: 625 Reward: 19.903185010502057
# Total Timesteps: 8881 Episode Num: 626 Reward: 27.768570806093347
# Total Timesteps: 8888 Episode Num: 627 Reward: 11.52269778956397
# Total Timesteps: 8902 Episode Num: 628 Reward: 15.789284904819212
# Total Timesteps: 8920 Episode Num: 629 Reward: 19.197734178956306
# Total Timesteps: 8939 Episode Num: 630 Reward: 20.626622370263792
# Total Timesteps: 8952 Episode Num: 631 Reward: 17.052547198919637
# Total Timesteps: 8963 Episode Num: 632 Reward: 14.03064864987682
# Total Timesteps: 10900 Episode Num: 720 Reward: 69.02745054530597
# Total Timesteps: 10973 Episode Num: 721 Reward: 85.59673466921312
# Total Timesteps: 11037 Episode Num: 722 Reward: 78.111868456753
# Total Timesteps: 11103 Episode Num: 723 Reward: 79.94951588166614
# Total Timesteps: 11149 Episode Num: 724 Reward: 59.40292113070751
# Total Timesteps: 11205 Episode Num: 725 Reward: 66.40793313817396
# Total Timesteps: 11272 Episode Num: 726 Reward: 72.82528314287964
# Total Timesteps: 11323 Episode Num: 727 Reward: 58.574271409441174
# Total Timesteps: 11399 Episode Num: 728 Reward: 76.64750969264222
# ...
# Total Timesteps: 342357 Episode Num: 1632 Reward: 1583.4433903355887
# Total Timesteps: 343357 Episode Num: 1633 Reward: 1414.56766036158
# Total Timesteps: 344357 Episode Num: 1634 Reward: 1499.7653171036582
# Total Timesteps: 344426 Episode Num: 1635 Reward: 59.68109285897611
# Total Timesteps: 345426 Episode Num: 1636 Reward: 1517.8442655263316
# ----------------------------------------
# Average Reward over the evaluation step: 1092.461079
# ----------------------------------------
# Total Timesteps: 346426 Episode Num: 1637 Reward: 1340.476385021155
# Total Timesteps: 347426 Episode Num: 1638 Reward: 1448.3675249060143
# Total Timesteps: 348426 Episode Num: 1639 Reward: 1521.4667669869443
# Total Timesteps: 349426 Episode Num: 1640 Reward: 1445.338419183885
# Total Timesteps: 350426 Episode Num: 1641 Reward: 1696.4777679568506
# ----------------------------------------
# Average Reward over the evaluation step: 1711.312181
# ----------------------------------------
# Total Timesteps: 351426 Episode Num: 1642 Reward: 1681.3769156190758
# Total Timesteps: 352426 Episode Num: 1643 Reward: 1742.0553313655055
# Total Timesteps: 353426 Episode Num: 1644 Reward: 1521.7157095522862
# Total Timesteps: 354139 Episode Num: 1645 Reward: 1169.1086370711105
# Total Timesteps: 355139 Episode Num: 1646 Reward: 1792.4797754624008
# ----------------------------------------
# Average Reward over the evaluation step: 623.193301
# ----------------------------------------
# Total Timesteps: 355181 Episode Num: 1647 Reward: 38.415096587038796
# Total Timesteps: 356181 Episode Num: 1648 Reward: 1729.2097676349886
# Total Timesteps: 357181 Episode Num: 1649 Reward: 1728.4562975674148
# Total Timesteps: 358181 Episode Num: 1650 Reward: 1671.0076258537777
# Total Timesteps: 359181 Episode Num: 1651 Reward: 1718.7039421005113
# Total Timesteps: 360181 Episode Num: 1652 Reward: 1686.1216698907454
# ----------------------------------------
# Average Reward over the evaluation step: 1734.988863
# ----------------------------------------
# Total Timesteps: 361181 Episode Num: 1653 Reward: 1692.2355969899486
# Total Timesteps: 362181 Episode Num: 1654 Reward: 1699.3551273942546
# Total Timesteps: 363181 Episode Num: 1655 Reward: 1581.1028293868599
# Total Timesteps: 364181 Episode Num: 1656 Reward: 1600.6063807841447
# Total Timesteps: 365181 Episode Num: 1657 Reward: 1554.0760283412935
# ----------------------------------------
# Average Reward over the evaluation step: 1578.711421
# ----------------------------------------
# Total Timesteps: 366181 Episode Num: 1658 Reward: 1597.5374828748486
# Total Timesteps: 367181 Episode Num: 1659 Reward: 1591.7698125221307
# Total Timesteps: 368181 Episode Num: 1660 Reward: 1544.0047010945063
# Total Timesteps: 369181 Episode Num: 1661 Reward: 1580.1964957281207
# Total Timesteps: 370181 Episode Num: 1662 Reward: 1496.2274270559594
# ----------------------------------------
# Average Reward over the evaluation step: 300.089200
# ----------------------------------------
# Total Timesteps: 370320 Episode Num: 1663 Reward: 172.21160002672616
# Total Timesteps: 370587 Episode Num: 1664 Reward: 399.1633763794851
# Total Timesteps: 371297 Episode Num: 1665 Reward: 1039.4695108696835
# Total Timesteps: 372297 Episode Num: 1666 Reward: 1561.971174618165
# Total Timesteps: 373297 Episode Num: 1667 Reward: 1465.7108138129804
# Total Timesteps: 374297 Episode Num: 1668 Reward: 1513.7005243089218
# Total Timesteps: 375297 Episode Num: 1669 Reward: 1571.8430955097717
# ----------------------------------------
# Average Reward over the evaluation step: 1023.574104
# ----------------------------------------
# Total Timesteps: 376297 Episode Num: 1670 Reward: 1619.2919324896081
# Total Timesteps: 377297 Episode Num: 1671 Reward: 1541.5617626372587
# Total Timesteps: 378297 Episode Num: 1672 Reward: 1568.968376377113
# Total Timesteps: 379297 Episode Num: 1673 Reward: 1540.7761821935983
# Total Timesteps: 380297 Episode Num: 1674 Reward: 1560.6063427483923
# ----------------------------------------
# Average Reward over the evaluation step: 1700.938296
# ----------------------------------------
# Total Timesteps: 381297 Episode Num: 1675 Reward: 1684.4135393287045
# Total Timesteps: 382297 Episode Num: 1676 Reward: 1555.4341471518126
# Total Timesteps: 383297 Episode Num: 1677 Reward: 1772.876273768953
# Total Timesteps: 384297 Episode Num: 1678 Reward: 1796.6504539602395
# Total Timesteps: 385297 Episode Num: 1679 Reward: 1742.1673669505892
# ----------------------------------------
# Average Reward over the evaluation step: 1825.016734
# ----------------------------------------
# Total Timesteps: 386297 Episode Num: 1680 Reward: 1755.422371500079
# Total Timesteps: 387297 Episode Num: 1681 Reward: 1706.9937028933168
# Total Timesteps: 388297 Episode Num: 1682 Reward: 1820.3671619089198
# Total Timesteps: 389297 Episode Num: 1683 Reward: 1763.3753908595543
# Total Timesteps: 389510 Episode Num: 1684 Reward: 348.7144434913193
# Total Timesteps: 390510 Episode Num: 1685 Reward: 1748.719317424294
# ----------------------------------------
# Average Reward over the evaluation step: 1548.941263
# ----------------------------------------
# Total Timesteps: 391510 Episode Num: 1686 Reward: 1542.1689815121924
# Total Timesteps: 392510 Episode Num: 1687 Reward: 1729.2942590291977
# Total Timesteps: 393510 Episode Num: 1688 Reward: 1599.3119359217324
# Total Timesteps: 394510 Episode Num: 1689 Reward: 1642.0603861251466
# Total Timesteps: 395510 Episode Num: 1690 Reward: 1563.242997632143
# ----------------------------------------
# Average Reward over the evaluation step: 1570.759790
# ----------------------------------------
# Total Timesteps: 396510 Episode Num: 1691 Reward: 1578.6015286232564
# Total Timesteps: 397510 Episode Num: 1692 Reward: 1583.8581171900619
# Total Timesteps: 398510 Episode Num: 1693 Reward: 1705.082849539967
# Total Timesteps: 399510 Episode Num: 1694 Reward: 1557.7743358776113
# Total Timesteps: 400510 Episode Num: 1695 Reward: 1579.3360094631255
# ----------------------------------------
# Average Reward over the evaluation step: 1627.350705
# ----------------------------------------
# Total Timesteps: 401510 Episode Num: 1696 Reward: 1600.3109446801384
# Total Timesteps: 402510 Episode Num: 1697 Reward: 1770.919349918719
# Total Timesteps: 403510 Episode Num: 1698 Reward: 1718.590319169279
# Total Timesteps: 404510 Episode Num: 1699 Reward: 1713.129806727512
# Total Timesteps: 405510 Episode Num: 1700 Reward: 1678.056232828341
# ----------------------------------------
# Average Reward over the evaluation step: 1584.356963
# ----------------------------------------
# Total Timesteps: 406510 Episode Num: 1701 Reward: 1563.5897016693416
# Total Timesteps: 407510 Episode Num: 1702 Reward: 1712.8069960055416
# Total Timesteps: 408510 Episode Num: 1703 Reward: 1692.1023042287493
# Total Timesteps: 409510 Episode Num: 1704 Reward: 1607.1763312764133
# Total Timesteps: 410510 Episode Num: 1705 Reward: 1465.7355166543157
# ----------------------------------------
# Average Reward over the evaluation step: 1598.752096
# ----------------------------------------
# Total Timesteps: 411510 Episode Num: 1706 Reward: 1569.2286491371271
# Total Timesteps: 412510 Episode Num: 1707 Reward: 1623.6436484253945
# Total Timesteps: 413510 Episode Num: 1708 Reward: 1672.6382762948376
# Total Timesteps: 414510 Episode Num: 1709 Reward: 1528.2820311543344
# Total Timesteps: 415510 Episode Num: 1710 Reward: 1743.7279966270262
# ----------------------------------------
# Average Reward over the evaluation step: 1645.790765
# ----------------------------------------
# Total Timesteps: 416510 Episode Num: 1711 Reward: 1591.3388146226612
# Total Timesteps: 417510 Episode Num: 1712 Reward: 1712.7292004898911
# Total Timesteps: 418510 Episode Num: 1713 Reward: 1665.3061376830835
# Total Timesteps: 419510 Episode Num: 1714 Reward: 1640.9484840026698
# Total Timesteps: 420510 Episode Num: 1715 Reward: 1650.7276111087888
# ----------------------------------------
# Average Reward over the evaluation step: 1808.087431
# ----------------------------------------
# Total Timesteps: 421510 Episode Num: 1716 Reward: 1781.3489966197071
# Total Timesteps: 422510 Episode Num: 1717 Reward: 1715.4911760808413
# Total Timesteps: 423510 Episode Num: 1718 Reward: 1736.0946929536135
# Total Timesteps: 424510 Episode Num: 1719 Reward: 1741.8149717670678
# Total Timesteps: 425510 Episode Num: 1720 Reward: 1732.11193907606
# ----------------------------------------
# Average Reward over the evaluation step: 1664.186511
# ----------------------------------------
# Total Timesteps: 426510 Episode Num: 1721 Reward: 1603.2048017577886
# Total Timesteps: 427510 Episode Num: 1722 Reward: 1555.0943206934598
# Total Timesteps: 428510 Episode Num: 1723 Reward: 1633.4935390175644
# Total Timesteps: 429510 Episode Num: 1724 Reward: 1624.25238886917
# Total Timesteps: 430510 Episode Num: 1725 Reward: 1746.354527791501
# ----------------------------------------
# Average Reward over the evaluation step: 1259.040922
# ----------------------------------------
# Total Timesteps: 430708 Episode Num: 1726 Reward: 314.3914881852039
# Total Timesteps: 430907 Episode Num: 1727 Reward: 298.5803144461574
# Total Timesteps: 431907 Episode Num: 1728 Reward: 1707.1771828390408
# Total Timesteps: 432907 Episode Num: 1729 Reward: 1679.2623655889115
# Total Timesteps: 433907 Episode Num: 1730 Reward: 1717.4258013940323
# Total Timesteps: 434907 Episode Num: 1731 Reward: 1718.7722546558368
# Total Timesteps: 435907 Episode Num: 1732 Reward: 1640.7909258007658
# ----------------------------------------
# Average Reward over the evaluation step: 1590.409125
# ----------------------------------------
# Total Timesteps: 436725 Episode Num: 1733 Reward: 1363.8991204665667
# Total Timesteps: 437725 Episode Num: 1734 Reward: 1611.6100923156189
# Total Timesteps: 438725 Episode Num: 1735 Reward: 1633.7228784146018
# Total Timesteps: 439725 Episode Num: 1736 Reward: 1686.0478388020686
# Total Timesteps: 440725 Episode Num: 1737 Reward: 1692.2236211435684
# ----------------------------------------
# Average Reward over the evaluation step: 1796.408092
# ----------------------------------------
# Total Timesteps: 441725 Episode Num: 1738 Reward: 1738.322684503897
# Total Timesteps: 442725 Episode Num: 1739 Reward: 1716.3408043387906
# Total Timesteps: 443725 Episode Num: 1740 Reward: 1696.2378996898285
# Total Timesteps: 444725 Episode Num: 1741 Reward: 1688.5270590439493
# Total Timesteps: 445725 Episode Num: 1742 Reward: 1743.5043765121193
# ----------------------------------------
# Average Reward over the evaluation step: 1720.951589
# ----------------------------------------
# Total Timesteps: 446725 Episode Num: 1743 Reward: 1584.2126310882586
# Total Timesteps: 447725 Episode Num: 1744 Reward: 1768.89287261948
# Total Timesteps: 448725 Episode Num: 1745 Reward: 1737.9043977114763
# Total Timesteps: 449725 Episode Num: 1746 Reward: 1792.36057649854
# Total Timesteps: 450725 Episode Num: 1747 Reward: 1647.4527723087604
# ----------------------------------------
# Average Reward over the evaluation step: 1794.279663
# ----------------------------------------
# Total Timesteps: 451725 Episode Num: 1748 Reward: 1787.0126849412434
# Total Timesteps: 452725 Episode Num: 1749 Reward: 1670.9763085623908
# Total Timesteps: 453725 Episode Num: 1750 Reward: 1678.9695673862907
# Total Timesteps: 454725 Episode Num: 1751 Reward: 1534.8560980852283
# Total Timesteps: 455725 Episode Num: 1752 Reward: 1592.7586442607092
# ----------------------------------------
# Average Reward over the evaluation step: 1623.956301
# ----------------------------------------
# Total Timesteps: 456725 Episode Num: 1753 Reward: 1574.1918113030029
# Total Timesteps: 457725 Episode Num: 1754 Reward: 1576.5499709724286
# Total Timesteps: 458725 Episode Num: 1755 Reward: 1501.4308430768995
# Total Timesteps: 459725 Episode Num: 1756 Reward: 1462.0981025474146
# Total Timesteps: 460725 Episode Num: 1757 Reward: 1516.654368123247
# ----------------------------------------
# Average Reward over the evaluation step: 1600.409509
# ----------------------------------------
# Total Timesteps: 461725 Episode Num: 1758 Reward: 1564.5409395257168
# Total Timesteps: 462725 Episode Num: 1759 Reward: 1646.3131638380776
# Total Timesteps: 463725 Episode Num: 1760 Reward: 1738.7625448971119
# Total Timesteps: 464725 Episode Num: 1761 Reward: 1756.9193056658132
# Total Timesteps: 465725 Episode Num: 1762 Reward: 1483.9803127211771
# ----------------------------------------
# Average Reward over the evaluation step: 1724.857603
# ----------------------------------------
# Total Timesteps: 466725 Episode Num: 1763 Reward: 1696.9144441804651
# Total Timesteps: 467725 Episode Num: 1764 Reward: 1634.6487752049406
# Total Timesteps: 468725 Episode Num: 1765 Reward: 1647.7160376564989
# Total Timesteps: 469725 Episode Num: 1766 Reward: 1783.273563770356
# Total Timesteps: 470725 Episode Num: 1767 Reward: 1732.1421819555285
# ----------------------------------------
# Average Reward over the evaluation step: 1674.239324
# ----------------------------------------
# Total Timesteps: 471725 Episode Num: 1768 Reward: 1636.939509124905
# Total Timesteps: 472725 Episode Num: 1769 Reward: 1709.5833936944882
# Total Timesteps: 473485 Episode Num: 1770 Reward: 1240.9431821403034
# Total Timesteps: 474485 Episode Num: 1771 Reward: 1713.4007937196552
# Total Timesteps: 475485 Episode Num: 1772 Reward: 1737.0128048202785
# ----------------------------------------
# Average Reward over the evaluation step: 870.167527
# ----------------------------------------
# Total Timesteps: 475640 Episode Num: 1773 Reward: 243.49403685831427
# Total Timesteps: 475965 Episode Num: 1774 Reward: 561.2017890841094
# Total Timesteps: 476965 Episode Num: 1775 Reward: 1817.8346665612967
# Total Timesteps: 477893 Episode Num: 1776 Reward: 1642.576022674787
# Total Timesteps: 478893 Episode Num: 1777 Reward: 1804.7824047009724
# Total Timesteps: 479893 Episode Num: 1778 Reward: 1810.4516851098974
# Total Timesteps: 480893 Episode Num: 1779 Reward: 1776.0662080755103
# ----------------------------------------
# Average Reward over the evaluation step: 1596.649222
# ----------------------------------------
# Total Timesteps: 481164 Episode Num: 1780 Reward: 459.4516039036721
# Total Timesteps: 481468 Episode Num: 1781 Reward: 507.33326074362304
# Total Timesteps: 482468 Episode Num: 1782 Reward: 1703.6529635565842
# Total Timesteps: 483468 Episode Num: 1783 Reward: 1801.746594861197
# Total Timesteps: 483852 Episode Num: 1784 Reward: 677.7792779342017
# Total Timesteps: 484852 Episode Num: 1785 Reward: 1809.5496632925522
# Total Timesteps: 485084 Episode Num: 1786 Reward: 387.1659734420589
# ----------------------------------------
# Average Reward over the evaluation step: 1787.152556
# ----------------------------------------
# Total Timesteps: 486084 Episode Num: 1787 Reward: 1705.0132770386085
# Total Timesteps: 487084 Episode Num: 1788 Reward: 1686.649847147379
# Total Timesteps: 488084 Episode Num: 1789 Reward: 1635.151775109866
# Total Timesteps: 489084 Episode Num: 1790 Reward: 1674.8919472503412
# Total Timesteps: 490084 Episode Num: 1791 Reward: 1774.8653637254597
# ----------------------------------------
# Average Reward over the evaluation step: 1697.108845
# ----------------------------------------
# Total Timesteps: 491084 Episode Num: 1792 Reward: 1694.2679610812984
# Total Timesteps: 492084 Episode Num: 1793 Reward: 1734.220921662965
# Total Timesteps: 493084 Episode Num: 1794 Reward: 1696.6354215055587
# Total Timesteps: 494084 Episode Num: 1795 Reward: 1690.4344908123849
# Total Timesteps: 495084 Episode Num: 1796 Reward: 1738.233453366128
# ----------------------------------------
# Average Reward over the evaluation step: 1554.461243
# ----------------------------------------
# Total Timesteps: 496084 Episode Num: 1797 Reward: 1678.9700286076184
# Total Timesteps: 497084 Episode Num: 1798 Reward: 1690.3247750100584
# Total Timesteps: 498084 Episode Num: 1799 Reward: 1663.1129374978186
# Total Timesteps: 499084 Episode Num: 1800 Reward: 1795.1485869413516
# ----------------------------------------
# Average Reward over the evaluation step: 1653.562019
# ----------------------------------------

# %% [markdown]
# # Infrence

# %%
class Actor(nn.Module):
    
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()
        self.layer_1 = nn.Linear(state_dim, 400)
        self.layer_2 = nn.Linear(400, 300)
        self.layer_3 = nn.Linear(300, action_dim)
        self.max_action = max_action
        
    def forward(self, x):
        x = F.relu(self.layer_1(x))
        x = F.relu(self.layer_2(x))
        x = self.max_action*torch.tanh(self.layer_3(x))
        return x
    
class Critic(nn.Module):
    
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()
        # first twin NN model
        self.layer_1 = nn.Linear(state_dim+action_dim, 400)
        self.layer_2 = nn.Linear(400, 300)
        self.layer_3 = nn.Linear(300, 1)
        # Second twin NN model
        self.layer_4 = nn.Linear(state_dim+action_dim, 400)
        self.layer_5 = nn.Linear(400, 300)
        self.layer_6 = nn.Linear(300, 1)
        
    def forward(self, x, u):
        xu = torch.cat([x, u], axis = 1)
        #first propoagation
        x1 = F.relu(self.layer_1(xu))
        x1 = F.relu(self.layer_2(xu))
        x1 = self.layer_3(xu)
        # second propogation
        x2 = F.relu(self.layer_4(xu))
        x2 = F.relu(self.layer_5(xu))
        x2 = self.layer_6(xu)
        return x1, x2
    
    def q1(self, x, u):
        xu = torch.cat([x, u], axis = 1)
        x1 = F.relu(self.layer_1(xu))
        x1 = F.relu(self.layer_2(xu))
        x1 = self.layer_3(xu)
        return x1
    
#Slecting the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class TD3(object):
    
    def __init__(self, state_dim, action_dim, max_action):
        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target = Actor (state_dim, action_dim, max_action).to(device)
        self.actor_target.load_state_dict(self.actor.state_dict())
        self.actor_optimizer = torch.optim.Adam(params = self.actor.parameters())
        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = Critic (state_dim, action_dim).to(device)
        self.critic_target.load_state_dict(self.critic.state_dict())
        self.critic_optimizer = torch.optim.Adam(params = self.critic.parameters())
        self.max_action = max_action
        
    def select_action(self, state):
        state = torch.Tensor(state.reshape(1,-1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()
    
    def train(self, replay_buffer, iterations, batch_size=100, discount = .99, tau=.005, policy_noise=.2, noise_clip=.5, policy_freq=2):
        
        for it in range(iterations):
            # Step4: we sample a batch of transitions (s,s',a,r) from emory
            batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = replay_buffer.sample(batch_size)
            state = torch.Tensor(batch_states).to(device)
            next_state = torch.Tensor(batch_next_states).to(device)
            action = torch.Tensor(batch_actions).to(device)
            reward = torch.Tensor(batch_rewards).to(device)
            done = torch.Tensor(batch_dones).to(device)
            
            # Step5: from the next state s', the Actor target plays the next action a'
            next_action = self.actor_target.forward(next_state)
            
            # Step6: add gaussian noise to next_action and we clamp(clip) it in arange of values supported by the environmenrt
            noise = torch.Tensor(batch_actions).data.normal_(0, policy_noise).to(device)
            noise = noise.clamp(-noise_clip,noise_clip)
            next_action = (next_action + noise).clamp(-self.max_action, self.max_action)
            
            # Step7: two critic target get (s',a') and return qt1(s',a'), qt2(s', a')
            target_q1, target_q2 = self.critic_target.forward(next_state, next_action)
            
            # Step8: min(q_values) to represent approximate values of the next state
            target_q = torch.min(target_q1, target_q2)
            
            # Step9: Final target of the two critic model(here we have to consider if we are in the last transition of episode or not)
            target_q = reward + ((1-done) * discount * target_q).detach()
            
            # Step10: two critic model take (s,a) and return Q1(s,a), Q2(s,a) with target Q
            current_q1, current_q2 = self.critic.forward(state, action)
            
            # Step11: calculate loss function with mse
            critic_loss = F.mse_loss(current_q1, target_q) + F.mse_loss(current_q2, target_q)
            
            # Step12: BackPropogation
            self.critic_optimizer.zero_grad()
            critic_loss.backward()
            self.critic_optimizer.step()
            
            # Step13: update actor model by gradient ascent
            # Gradient ascent that is very impormant:
            # Gradient descent is minimizing a function and gradient ascent is like gradient descent but in minus of that function
            if it % policy_freq == 0:
                actor_loss = -self.critic.q1(state, self.actor(state)).mean()
                self.actor_optimizer.zero_grad()
                actor_loss.backward()
                self.actor_optimizer.step()
                
                # Step14: update weights of the actor target by polyak average
                for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                    target_param.data.copy_(tau*param.data +(1 - tau)*target_patam.data)
                    
                    
                # Step15: update wights of the critic target by polyak average
                for param, target_param in zip(sel.critic.parameters(), self.critic_target.parameters()):
                    target_param.data.copy_(tau*param.data +(1-tau)*target_param.data)


        
        
def evaluate_policy(policy, eval_episodes = 10):
    avg_reward = 0
    for _ in range(eval_episodes):
        obs = env.reset()
        done = False
        while not done:
            action = policy.select_action(np.array(obs))
            obs, reward, done, _ = env.step(action)
            avg_reward += reward
    avg_reward /= eval_episodes
    print("----------------------------------------")
    print("Average Reward over the evaluation step: %f" % (avg_reward))
    print("----------------------------------------")
        
    return avg_reward
    

env_name = "Walker2DBulletEnv-v0" # Name of a environment (set it to any Continous environment you want)
seed = 0 # Random seed number

file_name = "%s%s%s" %("TD3", env_name, str(seed))
print ("---------------------------------------")
print ("Settings: %s" % (file_name))
print ("---------------------------------------")

eval_episodes = 10
save_env_vid = True


env = gym.make(env_name)
max_episode_steps = env._max_episode_steps


if save_env_vid:
    env = wrappers.Monitor(env, monitor_dir, force = True)
    env.reset()
    
    
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])
policy = TD3(state_dim, action_dim, max_action)

policy.actor.load_state_dict(torch.load("pytorch_modelsTD3_Walker2DBulletEnv-v0_0_actor.pth"))
policy.critic.load_state_dict(torch.load("pytorch_modelsTD3_Walker2DBulletEnv-v0_0_critic.pth"))

_ = evaluate_policy(policy, eval_episodes=eval_episodes)
# Out:
# ---------------------------------------
# Settings: TD3Walker2DBulletEnv-v00
# ---------------------------------------
# ----------------------------------------
# Average Reward over the evaluation step: 1672.311298
# ----------------------------------------
